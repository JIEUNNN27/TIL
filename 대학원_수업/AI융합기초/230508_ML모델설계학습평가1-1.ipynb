# %% [markdown]
# # 1. 단순 션형 회귀 실습(1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([1930, 1940, 1950, 1965, 1972, 1982, 1992, 2010, 2016]).reshape(-1, 1)
y = [59, 62, 61, 62, 63, 68, 75, 76, 78]
plt.figure()
plt.title('life')
plt.xlabel('year')
plt.ylabel('age')
plt.plot(X, y)
#plt.axis([0, 100, 0, 100])
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
test_age= np.array([[2000]])
predicted_age= model.predict(test_age)[0]
print('AGE: %.2f' % predicted_age)
# Out:
# AGE: 73.34

# %% [markdown]
# # 2. 단순 선형 회귀 실습 (2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X_train= X
y_train= y
X_test= np.array([1975, 1980, 1985, 1990, 1991, 1993, 1996, 1998]).reshape(-1, 1)
y_test= [64, 66, 68, 71, 72, 73, 74, 75]
model = LinearRegression()
model.fit(X_train, y_train)
r_squared= model.score(X_test, y_test)
print(r_squared)
# Out:
# 0.7003244361309551

# %% [markdown]
# # 3. 다항 회귀 실습

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## 2차

# %%
X_train= [[6], [8], [10], [14], [18]]
y_train= [[7], [9], [13], [17.5], [18]]
X_test= [[6], [8], [11], [16]]
y_test= [[8], [12], [15], [18]]
regressor= LinearRegression()
regressor.fit(X_train, y_train)
xx = np.linspace(0, 26, 100)
yy= regressor.predict(xx.reshape(xx.shape[0], 1))
plt.plot(xx, yy)

#2차
quadratic_featurizer= PolynomialFeatures(degree=2)
X_train_quadratic= quadratic_featurizer.fit_transform(X_train)
X_test_quadratic= quadratic_featurizer.transform(X_test)


regressor_quadratic= LinearRegression()
regressor_quadratic.fit(X_train_quadratic, y_train)
xx_quadratic= quadratic_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_quadratic.predict(xx_quadratic), c='r', linestyle='--')
plt.title('Pizza price regressed on diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.scatter(X_train, y_train)
plt.show()
print(X_train)
print(X_train_quadratic)
print(X_test)
print(X_test_quadratic)
print('Simple linear regression r-squared', regressor.score(X_test, y_test))
print('Quadratic regression r-squared', regressor_quadratic.score(X_test_quadratic, y_test))
# Out:
# [[6], [8], [10], [14], [18]]
# [[  1.   6.  36.]
#  [  1.   8.  64.]
#  [  1.  10. 100.]
#  [  1.  14. 196.]
#  [  1.  18. 324.]]
# [[6], [8], [11], [16]]
# [[  1.   6.  36.]
#  [  1.   8.  64.]
#  [  1.  11. 121.]
#  [  1.  16. 256.]]
# Simple linear regression r-squared 0.809726797707665
# Quadratic regression r-squared 0.8675443656345054

# %% [markdown]
# ## 3차

# %%
X_train= [[6], [8], [10], [14], [18]]
y_train= [[7], [9], [13], [17.5], [18]]
X_test= [[6], [8], [11], [16]]
y_test= [[8], [12], [15], [18]]
regressor= LinearRegression()
regressor.fit(X_train, y_train)
xx = np.linspace(0, 26, 100)
yy= regressor.predict(xx.reshape(xx.shape[0], 1))
plt.plot(xx, yy)

#3차
trigeminal_featurizer= PolynomialFeatures(degree=3)
X_train_trigeminal= trigeminal_featurizer.fit_transform(X_train)
X_test_trigeminal= trigeminal_featurizer.transform(X_test)


regressor_trigeminal= LinearRegression()
regressor_trigeminal.fit(X_train_trigeminal, y_train)
xx_trigeminal= trigeminal_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_trigeminal.predict(xx_trigeminal), c='r', linestyle='--')
plt.title('Pizza price regressed on diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.scatter(X_train, y_train)
plt.show()
print(X_train)
print(X_train_trigeminal)
print(X_test)
print(X_test_trigeminal)
print('Simple linear regression r-squared', regressor.score(X_test, y_test))
print('Quadratic regression r-squared', regressor_trigeminal.score(X_test_trigeminal, y_test))
# Out:
# [[6], [8], [10], [14], [18]]
# [[1.000e+00 6.000e+00 3.600e+01 2.160e+02]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02]
#  [1.000e+00 1.000e+01 1.000e+02 1.000e+03]
#  [1.000e+00 1.400e+01 1.960e+02 2.744e+03]
#  [1.000e+00 1.800e+01 3.240e+02 5.832e+03]]
# [[6], [8], [11], [16]]
# [[1.000e+00 6.000e+00 3.600e+01 2.160e+02]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02]
#  [1.000e+00 1.100e+01 1.210e+02 1.331e+03]
#  [1.000e+00 1.600e+01 2.560e+02 4.096e+03]]
# Simple linear regression r-squared 0.809726797707665
# Quadratic regression r-squared 0.835692415603779

# %% [markdown]
# ## 4차

# %%
X_train= [[6], [8], [10], [14], [18]]
y_train= [[7], [9], [13], [17.5], [18]]
X_test= [[6], [8], [11], [16]]
y_test= [[8], [12], [15], [18]]
regressor= LinearRegression()
regressor.fit(X_train, y_train)
xx = np.linspace(0, 26, 100)
yy= regressor.predict(xx.reshape(xx.shape[0], 1))
plt.plot(xx, yy)

#4차
biquadratic_featurizer= PolynomialFeatures(degree=4)
X_train_biquadratic= biquadratic_featurizer.fit_transform(X_train)
X_test_biquadratic= biquadratic_featurizer.transform(X_test)


regressor_biquadratic= LinearRegression()
regressor_biquadratic.fit(X_train_biquadratic, y_train)
xx_biquadratic= biquadratic_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_biquadratic.predict(xx_biquadratic), c='r', linestyle='--')
plt.title('Pizza price regressed on diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.scatter(X_train, y_train)
plt.show()
print(X_train)
print(X_train_biquadratic)
print(X_test)
print(X_test_biquadratic)
print('Simple linear regression r-squared', regressor.score(X_test, y_test))
print('Quadratic regression r-squared', regressor_biquadratic.score(X_test_biquadratic, y_test))
# Out:
# [[6], [8], [10], [14], [18]]
# [[1.00000e+00 6.00000e+00 3.60000e+01 2.16000e+02 1.29600e+03]
#  [1.00000e+00 8.00000e+00 6.40000e+01 5.12000e+02 4.09600e+03]
#  [1.00000e+00 1.00000e+01 1.00000e+02 1.00000e+03 1.00000e+04]
#  [1.00000e+00 1.40000e+01 1.96000e+02 2.74400e+03 3.84160e+04]
#  [1.00000e+00 1.80000e+01 3.24000e+02 5.83200e+03 1.04976e+05]]
# [[6], [8], [11], [16]]
# [[1.0000e+00 6.0000e+00 3.6000e+01 2.1600e+02 1.2960e+03]
#  [1.0000e+00 8.0000e+00 6.4000e+01 5.1200e+02 4.0960e+03]
#  [1.0000e+00 1.1000e+01 1.2100e+02 1.3310e+03 1.4641e+04]
#  [1.0000e+00 1.6000e+01 2.5600e+02 4.0960e+03 6.5536e+04]]
# Simple linear regression r-squared 0.809726797707665
# Quadratic regression r-squared 0.8095880795745934

# %% [markdown]
# ## 5차

# %%
X_train= [[6], [8], [10], [14], [18]]
y_train= [[7], [9], [13], [17.5], [18]]
X_test= [[6], [8], [11], [16]]
y_test= [[8], [12], [15], [18]]
regressor= LinearRegression()
regressor.fit(X_train, y_train)
xx = np.linspace(0, 26, 100)
yy= regressor.predict(xx.reshape(xx.shape[0], 1))
plt.plot(xx, yy)

#5차
quintic_featurizer= PolynomialFeatures(degree=5)
X_train_quintic= quintic_featurizer.fit_transform(X_train)
X_test_quintic= quintic_featurizer.transform(X_test)


regressor_quintic= LinearRegression()
regressor_quintic.fit(X_train_quintic, y_train)
xx_quintic= quintic_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_quintic.predict(xx_quintic), c='r', linestyle='--')
plt.title('Pizza price regressed on diameter')
plt.xlabel('Diameter in inches')
plt.ylabel('Price in dollars')
plt.axis([0, 25, 0, 25])
plt.grid(True)
plt.scatter(X_train, y_train)
plt.show()
print(X_train)
print(X_train_quintic)
print(X_test)
print(X_test_quintic)
print('Simple linear regression r-squared', regressor.score(X_test, y_test))
print('Quadratic regression r-squared', regressor_quintic.score(X_test_quintic, y_test))
# Out:
# [[6], [8], [10], [14], [18]]
# [[1.000000e+00 6.000000e+00 3.600000e+01 2.160000e+02 1.296000e+03
#   7.776000e+03]
#  [1.000000e+00 8.000000e+00 6.400000e+01 5.120000e+02 4.096000e+03
#   3.276800e+04]
#  [1.000000e+00 1.000000e+01 1.000000e+02 1.000000e+03 1.000000e+04
#   1.000000e+05]
#  [1.000000e+00 1.400000e+01 1.960000e+02 2.744000e+03 3.841600e+04
#   5.378240e+05]
#  [1.000000e+00 1.800000e+01 3.240000e+02 5.832000e+03 1.049760e+05
#   1.889568e+06]]
# [[6], [8], [11], [16]]
# [[1.000000e+00 6.000000e+00 3.600000e+01 2.160000e+02 1.296000e+03
#   7.776000e+03]
#  [1.000000e+00 8.000000e+00 6.400000e+01 5.120000e+02 4.096000e+03
#   3.276800e+04]
#  [1.000000e+00 1.100000e+01 1.210000e+02 1.331000e+03 1.464100e+04
#   1.610510e+05]
#  [1.000000e+00 1.600000e+01 2.560000e+02 4.096000e+03 6.553600e+04
#   1.048576e+06]]
# Simple linear regression r-squared 0.809726797707665
# Quadratic regression r-squared 0.7821286109679371

# %% [markdown]
# ### 과적합 때문에 차수 늘어날수록 성능 떨어진다
