# %%
import pandas as pd

# %%
path = 'C:/Users/silvi/Desktop/230403/data/'

# %%
#파일 업로드
bank_df= pd.read_csv(path + 'bank.csv',sep=',')
bank_df.head()
# Out:
#    age          job  marital  education default  balance housing loan contact  \
# 0   58   management  married   tertiary      no     2143     yes   no     NaN
# 1   36   technician   single  secondary      no      265     yes  yes     NaN
# 2   25  blue-collar  married  secondary      no       -7     yes   no     NaN
# 3   53   technician  married  secondary      no       -3      no   no     NaN
# 4   24   technician   single  secondary      no     -103     yes  yes     NaN
#
#    day month  duration  campaign  pdays  previous poutcome   y
# 0    5   may       261         1     -1         0      NaN  no
# 1    5   may       348         1     -1         0      NaN  no
# 2    5   may       365         1     -1         0      NaN  no
# 3    5   may      1666         1     -1         0      NaN  no
# 4    5   may       145         1     -1         0      NaN  no

# %% [markdown]
# # Q. 10개행의내용을확인하려면어떻게해야할까요?

# %%
bank_df.head(10)
# Out:
#    age          job   marital  education default  balance housing loan  \
# 0   58   management   married   tertiary      no     2143     yes   no
# 1   36   technician    single  secondary      no      265     yes  yes
# 2   25  blue-collar   married  secondary      no       -7     yes   no
# 3   53   technician   married  secondary      no       -3      no   no
# 4   24   technician    single  secondary      no     -103     yes  yes
# 5   60      retired   married   tertiary      no      100      no   no
# 6   55   technician   married  secondary      no     1205     yes   no
# 7   54   management   married  secondary      no      282     yes  yes
# 8   55     services  divorced  secondary      no       91      no   no
# 9   56       admin.   married  secondary      no       45      no   no
#
#   contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     NaN    5   may       261         1     -1         0      NaN   no
# ...

# %%
#데이터행/열확인
print(bank_df.shape)
#데이터형확인
print(bank_df.dtypes)
# Out:
# (7234, 17)
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
#결손값확인
print(bank_df.isnull().any(axis=1)) #행방향결손값
print(bank_df.isnull().any(axis=0)) #열방향결손값
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7229    False
# 7230    False
# 7231    False
# 7232     True
# 7233     True
# Length: 7234, dtype: bool
# age          False
# job           True
# marital      False
# education     True
# default      False
# balance      False
# housing      False
# loan         False
# contact       True
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome      True
# y            False
# dtype: bool

# %%
#결손값개수확인
print(bank_df.isnull().sum(axis=1)) #행방향결손값
print(bank_df.isnull().sum(axis=0)) #열방향결손값
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 7229    0
# 7230    0
# 7231    0
# 7232    1
# 7233    1
# Length: 7234, dtype: int64
# age             0
# job            44
# marital         0
# education     273
# default         0
# balance         0
# housing         0
# loan            0
# contact      2038
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome     5900
# y               0
# dtype: int64

# %%
#결손값개수확인
print(bank_df.isnull().sum(axis=1)) #행방향결손값
print(bank_df.isnull().sum(axis=0)) #열방향결손값
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 7229    0
# 7230    0
# 7231    0
# 7232    1
# 7233    1
# Length: 7234, dtype: int64
# age             0
# job            44
# marital         0
# education     273
# default         0
# balance         0
# housing         0
# loan            0
# contact      2038
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome     5900
# y               0
# dtype: int64

# %%
#데이터형이int64인항목의통계량계산
bank_df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  7234.000000   7234.000000  7234.000000  7234.000000  7234.000000
# mean     40.834808   1374.912911    15.623860   262.875311     2.713989
# std      10.706442   3033.882933     8.307826   268.921065     2.983740
# min       2.000000  -3313.000000     1.000000     0.000000     1.000000
# 25%      33.000000     74.000000     8.000000   103.000000     1.000000
# 50%      39.000000    453.500000    16.000000   183.000000     2.000000
# 75%      48.000000   1470.750000    21.000000   321.750000     3.000000
# max     157.000000  81204.000000    31.000000  3366.000000    44.000000
#
#              pdays     previous
# count  7234.000000  7234.000000
# mean     40.277716     0.565939
# std      99.188008     1.825100
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     850.000000    40.000000

# %% [markdown]
# # Q. 데이터형이 object인 항목에 대해서는 통계값을 어떻게 계산해야할까요?

# %%
bank_df.describe(include = 'object')
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         7190     7234       6961    7234    7234  7234      5196  7234
# unique          11        3          3       2       2     2         2    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq          1560     4343       3745    7101    4058  6066      4697  2202
#
#        poutcome     y
# count      1334  7234
# unique        3     2
# top     failure    no
# freq        772  6381

# %%
bank_df['job'].value_counts()
# Out:
# management       1560
# blue-collar      1499
# technician       1206
# admin.            834
# services          661
# retired           351
# self-employed     256
# entrepreneur      239
# unemployed        223
# housemaid         208
# student           153
# Name: job, dtype: int64

# %% [markdown]
# 답:

# %%
#’age’에대한데이터시각화
import matplotlib.pyplot as plt

# %matplotlib inline
plt.hist(bank_df['age'])
plt.xlabel('age')
plt.ylabel('freq')
plt.show()

# %% [markdown]
# # Q. balance, day, duration, campaign, pdays, previous에 대해 각각 시각화하여 데이터 분포를 확인해 봅시다.

# %%
plt.hist(bank_df['balance'])
plt.xlabel('balance')
plt.ylabel('freq')
plt.show()

# %%
plt.hist(bank_df['day'])
plt.xlabel('day')
plt.ylabel('freq')
plt.show()

# %%
plt.hist(bank_df['duration'])
plt.xlabel('duration')
plt.ylabel('freq')
plt.show()

# %%
plt.hist(bank_df['campaign'])
plt.xlabel('campaign')
plt.ylabel('freq')
plt.show()

# %%
plt.hist(bank_df['pdays'])
plt.xlabel('pdays')
plt.ylabel('freq')
plt.show()

# %%
plt.hist(bank_df['previous'])
plt.xlabel('previous')
plt.ylabel('freq')
plt.show()

# %%
#age와balanc에대한관련성확인
plt.scatter(bank_df['age'], bank_df['balance'])ㄴ
plt.xlabel('age')
plt.ylabel('balance')
plt.show()
bank_df[['age', 'balance']].corr()
# Out:
#               age   balance
# age      1.000000  0.112364
# balance  0.112364  1.000000

# %%
#상관계수표시. -1~1 사이값. 값이클수록관련성이있음
